# %% [markdown]
# `python3 run_classifier.py\
#  --pretrained_model_path ../../user_data/mybert/pytorch_model.bin\
#  --vocab_path ../../user_data/mybert/vocab.txt\
#  --train_path ../../user_data/train.tsv\
#  --dev_path  ../../user_data/train.tsv\
#  --test_path ../../user_data/test.tsv\
#  --epochs_num 3 --batch_size 128 --embedding word_pos_seg --encoder transformer --mask fully_visible`

# %% [markdown]
# `python3 inference/run_classifier_infer.py\
#  --load_model_path ../../user_data/mybert/pytorch_model.bin\
#  --vocab_path  ../../user_data/mybert/vocab.txt\
#  --test_path ../../user_data/test.tsv\
#  --prediction_path datasets/douban_book_review/prediction.tsv --labels_num 2 \
#                                           --embedding word_pos_seg --encoder transformer --mask fully_visible`

# %% [markdown]
# !python3 run_classifier.py\
#  --pretrained_model_path ../../user_data/mybert/pytorch_model.bin\
#  --vocab_path ../../user_data/mybert/vocab.txt\
#  --train_path ../../user_data/train.tsv\
#  --dev_path  ../../user_data/train.tsv\
#  --test_path ../../user_data/test.tsv\
#  --epochs_num 3 --batch_size 128 --embedding word_pos_seg --encoder transformer --mask fully_visible

# %%
# !CUDA_VISIBLE_DEVICES=0 python run_classifier_cv.py\
 --pretrained_model_path ../../user_data/mybert/pytorch_model.bin\
 --vocab_path  ../../user_data/mybert/vocab.txt\
 --train_path ../../user_data/train.tsv\
 --tokenizer char\
 --folds_num 5\
 --seed 2021\
 --embedding word_pos_seg\
 --train_features_path ../../prediction_result/train_features_0.npy\
 --epochs_num 4 --batch_size 128 --embedding word_pos_seg --encoder transformer --mask fully_visible
# Out:
# Fold id: 0, Epoch id: 1, Training steps: 100, Avg loss: 0.647
# Fold id: 0, Epoch id: 1, Training steps: 200, Avg loss: 0.612
# Fold id: 0, Epoch id: 1, Training steps: 300, Avg loss: 0.609
# Fold id: 0, Epoch id: 1, Training steps: 400, Avg loss: 0.599
# Fold id: 0, Epoch id: 1, Training steps: 500, Avg loss: 0.595
# Fold id: 0, Epoch id: 1, Training steps: 600, Avg loss: 0.597
# Fold id: 0, Epoch id: 2, Training steps: 100, Avg loss: 0.737
# Fold id: 0, Epoch id: 2, Training steps: 200, Avg loss: 0.586
# Fold id: 0, Epoch id: 2, Training steps: 300, Avg loss: 0.592
# Fold id: 0, Epoch id: 2, Training steps: 400, Avg loss: 0.585
# Fold id: 0, Epoch id: 2, Training steps: 500, Avg loss: 0.584
# Fold id: 0, Epoch id: 2, Training steps: 600, Avg loss: 0.588
# Fold id: 0, Epoch id: 3, Training steps: 100, Avg loss: 0.727
# Fold id: 0, Epoch id: 3, Training steps: 200, Avg loss: 0.577
# Fold id: 0, Epoch id: 3, Training steps: 300, Avg loss: 0.583
# ...

# %%
# !cp -r ../UER  /wangjinfix/lin/智能医疗决策(NER)/code/UER
# Out:
# /bin/sh: 1: Syntax error: "(" unexpected
